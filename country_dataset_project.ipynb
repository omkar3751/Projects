# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('country.csv')

# %%
df[:50]
# Out:
#     id                              name alpha-2 alpha-3  country-code  \
# 0    1                       Afghanistan      AF     AFG             4
# 1    2                     Åland Islands      AX     ALA           248
# 2    3                           Albania      AL     ALB             8
# 3    4                           Algeria      DZ     DZA            12
# 4    5                    American Samoa      AS     ASM            16
# 5    6                           Andorra      AD     AND            20
# 6    7                            Angola      AO     AGO            24
# 7    8                          Anguilla      AI     AIA           660
# 8    9                        Antarctica      AQ     ATA            10
# 9   10               Antigua and Barbuda      AG     ATG            28
# 10  11                         Argentina      AR     ARG            32
# 11  12                           Armenia      AM     ARM            51
# ...

# %%
df.tail()
# Out:
#       id               name alpha-2 alpha-3  country-code     iso_3166-2  \
# 244  245  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF
# 245  246     Western Sahara      EH     ESH           732  ISO 3166-2:EH
# 246  247              Yemen      YE     YEM           887  ISO 3166-2:YE
# 247  248             Zambia      ZM     ZMB           894  ISO 3166-2:ZM
# 248  249           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW
#
#       region          sub-region intermediate-region  region-code  \
# 244  Oceania           Polynesia                 NaN          9.0
# 245   Africa     Northern Africa                 NaN          2.0
# 246     Asia        Western Asia                 NaN        142.0
# 247   Africa  Sub-Saharan Africa      Eastern Africa          2.0
# 248   Africa  Sub-Saharan Africa      Eastern Africa          2.0
#
#      sub-region-code  intermediate-region-code  population  Unnamed: 13  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        249 non-null    int64
#  1   name                      249 non-null    object
#  2   alpha-2                   248 non-null    object
#  3   alpha-3                   249 non-null    object
#  4   country-code              249 non-null    int64
#  5   iso_3166-2                249 non-null    object
#  6   region                    248 non-null    object
#  7   sub-region                248 non-null    object
#  8   intermediate-region       107 non-null    object
#  9   region-code               248 non-null    float64
#  10  sub-region-code           248 non-null    float64
#  11  intermediate-region-code  107 non-null    float64
#  12  population                249 non-null    int64
# ...

# %%
df.describe()
# Out:
#                id  country-code  region-code  sub-region-code  \
# count  249.000000    249.000000   248.000000       248.000000
# mean   125.000000    433.835341    65.951613       179.866935
# std     72.024301    252.980446    67.347832       138.334170
# min      1.000000      4.000000     2.000000        15.000000
# 25%     63.000000    218.000000     9.000000        53.750000
# 50%    125.000000    434.000000    19.000000       154.000000
# 75%    187.000000    652.000000   142.000000       202.000000
# max    249.000000    894.000000   150.000000       419.000000
#
#        intermediate-region-code    population  Unnamed: 13  population.1
# count                107.000000  2.490000e+02          0.0  2.490000e+02
# mean                  31.719626  3.083343e+07          NaN  3.083343e+07
# std                  111.000322  1.328347e+08          NaN  1.328347e+08
# min                    5.000000  5.100000e+02          NaN  5.100000e+02
# ...

# %%
df.describe(include='all')
# Out:
#                 id         name alpha-2 alpha-3  country-code     iso_3166-2  \
# count   249.000000          249     248     249    249.000000            249
# unique         NaN          249     248     249           NaN            249
# top            NaN  Afghanistan      AF     AFG           NaN  ISO 3166-2:AF
# freq           NaN            1       1       1           NaN              1
# mean    125.000000          NaN     NaN     NaN    433.835341            NaN
# std      72.024301          NaN     NaN     NaN    252.980446            NaN
# min       1.000000          NaN     NaN     NaN      4.000000            NaN
# 25%      63.000000          NaN     NaN     NaN    218.000000            NaN
# 50%     125.000000          NaN     NaN     NaN    434.000000            NaN
# 75%     187.000000          NaN     NaN     NaN    652.000000            NaN
# max     249.000000          NaN     NaN     NaN    894.000000            NaN
#
# ...

# %%
df.dtypes
# Out:
# id                            int64
# name                         object
# alpha-2                      object
# alpha-3                      object
# country-code                  int64
# iso_3166-2                   object
# region                       object
# sub-region                   object
# intermediate-region          object
# region-code                 float64
# sub-region-code             float64
# intermediate-region-code    float64
# population                    int64
# Unnamed: 13                 float64
# population.1                  int64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=249, step=1)

# %%
df.columns
# Out:
# Index(['id', 'name', 'alpha-2', 'alpha-3', 'country-code', 'iso_3166-2',
#        'region', 'sub-region', 'intermediate-region', 'region-code',
#        'sub-region-code', 'intermediate-region-code', 'population',
#        'Unnamed: 13', 'population.1'],
#       dtype='object')

# %%
df.size
# Out:
# 3735

# %%
df.shape                                                                                  # Show the Rows & Columns
# Out:
# (249, 15)

# %%
df.count()
# Out:
# id                          249
# name                        249
# alpha-2                     248
# alpha-3                     249
# country-code                249
# iso_3166-2                  249
# region                      248
# sub-region                  248
# intermediate-region         107
# region-code                 248
# sub-region-code             248
# intermediate-region-code    107
# population                  249
# Unnamed: 13                   0
# population.1                249
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                            0
# name                          0
# alpha-2                       1
# alpha-3                       0
# country-code                  0
# iso_3166-2                    0
# region                        1
# sub-region                    1
# intermediate-region         142
# region-code                   1
# sub-region-code               1
# intermediate-region-code    142
# population                    0
# Unnamed: 13                 249
# population.1                  0
# dtype: int64

# %%
df.duplicated().sum()                                                          # show the duplicate Record in that DataFrame
# Out:
# 0

# %%
df.T                                                                            # Transpose the dataset
# Out:
#                                     0                1                2    \
# id                                    1                2                3
# name                        Afghanistan    Åland Islands          Albania
# alpha-2                              AF               AX               AL
# alpha-3                             AFG              ALA              ALB
# country-code                          4              248                8
# iso_3166-2                ISO 3166-2:AF    ISO 3166-2:AX    ISO 3166-2:AL
# region                             Asia           Europe           Europe
# sub-region                Southern Asia  Northern Europe  Southern Europe
# intermediate-region                 NaN              NaN              NaN
# region-code                       142.0            150.0            150.0
# sub-region-code                    34.0            154.0             39.0
# intermediate-region-code            NaN              NaN              NaN
# ...

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18900\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                 id  country-code  region-code  \
# id                        1.000000      0.818820     0.017741
# country-code              0.818820      1.000000    -0.008380
# region-code               0.017741     -0.008380     1.000000
# sub-region-code          -0.100340     -0.053267    -0.428531
# intermediate-region-code -0.024691      0.224924     0.920485
# population               -0.033904     -0.042644     0.115962
# Unnamed: 13                    NaN           NaN          NaN
# population.1             -0.033904     -0.042644     0.115962
#
#                           sub-region-code  intermediate-region-code  \
# ...

# %% [markdown]
# # Heatmap Correlation

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18900\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# # Correlation With Heatmap Null values

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # DATA CLEANING

# %%
df.drop(['id','alpha-2','iso_3166-2','intermediate-region','intermediate-region-code','Unnamed: 13','population.1'],
        axis=1,inplace=True) # Drop the column

# %%
df.rename(columns={'name':'country_name'},inplace=True)                                           # Rename the column name

# %%
df.loc[df.region.isna(),'region'] = 'Americas'                                                  # Null values to fill

# %%
df.loc[df['sub-region'].isna(),'sub-region'] = 'Latin America and the Caribbean'

# %%
df.loc[df['region-code'].isna(),'region-code'] = '19.0'

# %%
df.loc[df['sub-region-code'].isna(),'sub-region-code'] = '419.0'

# %% [markdown]
# # Accessing the records Row & Column Wise

# %%
df.iloc[1:10]                                                                               # slicing the records Row wise
# Out:
#           country_name alpha-3  country-code    region  \
# 1        Åland Islands     ALA           248    Europe
# 2              Albania     ALB             8    Europe
# 3              Algeria     DZA            12    Africa
# 4       American Samoa     ASM            16   Oceania
# 5              Andorra     AND            20    Europe
# 6               Angola     AGO            24    Africa
# 7             Anguilla     AIA           660  Americas
# 8           Antarctica     ATA            10  Americas
# 9  Antigua and Barbuda     ATG            28  Americas
#
#                         sub-region region-code sub-region-code  population
# 1                  Northern Europe       150.0           154.0       48765
# 2                  Southern Europe       150.0            39.0     2842321
# 3                  Northern Africa         2.0            15.0    44903225
# 4                        Polynesia         9.0            61.0       44273
# ...

# %%
df.iloc[1:20,1:6]                                                                            # 1 to 20 Rows & 1 to 6 columns
# Out:
#    alpha-3  country-code    region                       sub-region  \
# 1      ALA           248    Europe                  Northern Europe
# 2      ALB             8    Europe                  Southern Europe
# 3      DZA            12    Africa                  Northern Africa
# 4      ASM            16   Oceania                        Polynesia
# 5      AND            20    Europe                  Southern Europe
# 6      AGO            24    Africa               Sub-Saharan Africa
# 7      AIA           660  Americas  Latin America and the Caribbean
# 8      ATA            10  Americas  Latin America and the Caribbean
# 9      ATG            28  Americas  Latin America and the Caribbean
# 10     ARG            32  Americas  Latin America and the Caribbean
# 11     ARM            51      Asia                     Western Asia
# 12     ABW           533  Americas  Latin America and the Caribbean
# 13     AUS            36   Oceania        Australia and New Zealand
# ...

# %%
df.loc[100:150,['country_name','country-code','region']]                                # 100 to 150 records & specific columns
# Out:
#                                     country_name  country-code    region
# 100                                    Hong Kong           344      Asia
# 101                                      Hungary           348    Europe
# 102                                      Iceland           352    Europe
# 103                                        India           356      Asia
# 104                                    Indonesia           360      Asia
# 105                   Iran (Islamic Republic of)           364      Asia
# 106                                         Iraq           368      Asia
# 107                                      Ireland           372    Europe
# 108                                  Isle of Man           833    Europe
# 109                                       Israel           376      Asia
# 110                                        Italy           380    Europe
# 111                                      Jamaica           388  Americas
# ...

# %%
df[['country_name','region','country-code']]
# Out:
#           country_name   region  country-code
# 0          Afghanistan     Asia             4
# 1        Åland Islands   Europe           248
# 2              Albania   Europe             8
# 3              Algeria   Africa            12
# 4       American Samoa  Oceania            16
# ..                 ...      ...           ...
# 244  Wallis and Futuna  Oceania           876
# 245     Western Sahara   Africa           732
# 246              Yemen     Asia           887
# 247             Zambia   Africa           894
# 248           Zimbabwe   Africa           716
#
# [249 rows x 3 columns]

# %%
df['country_name'].unique()                                                                     # print the unique values
# Out:
# array(['Afghanistan', 'Åland Islands', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire, Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Bouvet Island', 'Brazil',
#        'British Indian Ocean Territory', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Christmas Island', 'Cocos (Keeling) Islands',
#        'Colombia', 'Comoros', 'Congo',
#        'Congo (Democratic Republic of the)', 'Cook Islands', 'Costa Rica',
#        "Côte d'Ivoire", 'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
# ...

# %%
df[df['country_name'] =='India']                                                              # Country equal to India
# Out:
#     country_name alpha-3  country-code region     sub-region region-code  \
# 103        India     IND           356   Asia  Southern Asia       142.0
#
#     sub-region-code  population
# 103            34.0  1417173173

# %%
df['region'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'Americas'], dtype=object)

# %%
df[df['region']=='Asia']                                                                      # Region equal to Asia
# Out:
#                                 country_name alpha-3  country-code region  \
# 0                                Afghanistan     AFG             4   Asia
# 11                                   Armenia     ARM            51   Asia
# 15                                Azerbaijan     AZE            31   Asia
# 17                                   Bahrain     BHR            48   Asia
# 18                                Bangladesh     BGD            50   Asia
# 25                                    Bhutan     BTN            64   Asia
# 33                         Brunei Darussalam     BRN            96   Asia
# 38                                  Cambodia     KHM           116   Asia
# 45                                     China     CHN           156   Asia
# 58                                    Cyprus     CYP           196   Asia
# 82                                   Georgia     GEO           268   Asia
# 100                                Hong Kong     HKG           344   Asia
# ...

# %% [markdown]
# # DATA EXPLORATION / VISUALIZATION

# %%
plt.bar(df['region'],df['population'],label='region')                                       # region by population bar graph
plt.xlabel('Regions',color='red',fontsize=12)
plt.ylabel('Population',color='red',fontsize=12)
plt.legend()
plt.show()

# %%
plt.hist(df['region'],bins=9)                                                                 # region wise frequency
plt.xlabel('Regions',color='red',fontsize=16)
plt.ylabel('Frequency',color='red',fontsize=16)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.countplot(df['sub-region'],palette='rainbow')                                         # count the Sub-regions
plt.xlabel('Count',color='purple',fontsize=14)
plt.ylabel('Sub-region',color='purple',fontsize=14)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18900\3792185102.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df['sub-region'],palette='rainbow')                                         # count the Sub-regions
# Text(0, 0.5, 'Sub-region')

# %%
sns.barplot(df['region'],palette='rocket')                                                # barplot of region
plt.ylabel("Region",color = 'green',fontsize=15)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18900\4109930755.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(df['region'],palette='rocket')                                                # barplot of region
# Text(0, 0.5, 'Region')

# %%
sns.jointplot(x=df['region'],y=df['sub-region'])                                       # Region & Sub-region joint plot
